# %% [markdown]
# # 통계적 사고와 사회 — R 실습 (JupyterLite · webR)
#
# 브라우저에서 바로 실행되는 **R(webR)** 환경입니다. 설치 불필요.
#
# - 교재 데이터(CSV)는 `data/` 폴더에 미리 올려져 있습니다.
# - 이 노트북은 **R (webR)** 커널로 실행하세요(우상단 커널 표시 확인).
# - 첫 실행 시 webR 로딩에 시간이 걸립니다.

# %%
# 1) 데이터 불러오기
df <- read.csv('data/StudentSurvey.csv')
cat('행:', nrow(df), ' 열:', ncol(df), '\n')
head(df)

# %%
# 2) 요약 통계
summary(df$Pulse)

# %%
# 3) 히스토그램
hist(df$Pulse, breaks=20, col='#dc3545', border='white',
     main='맥박수 분포 (StudentSurvey)', xlab='Pulse')
